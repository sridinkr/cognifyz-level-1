# %% [markdown]
# <a href="https://colab.research.google.com/github/sridinkr/cognifyz-level-1/blob/main/Da_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
res=pd.read_csv("/Dataset .csv")
res.head()
top=res['Cuisines'].value_counts().head(3)
print(top)
per_cusines=(top/len(res))*100
print(per_cusines)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64
# Cuisines
# North Indian             9.800021
# North Indian, Chinese    5.350225
# Chinese                  3.706418
# Name: count, dtype: float64
